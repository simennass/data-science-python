# %% [markdown]
# # Getting started with data
#
# What does `data['vehicle_type_raw'].nunique()` give?
#
# Create a list of unique vehicle types (`vehicle_type_raw`) found in the data. Call it `vehicle_types`.

# %%
import pandas as pd
data = pd.read_csv('./data/trafikkregistreringspunkt_1_-_uke_42_og_43_2020.csv')

# %%
list(data['vehicle_type_raw'].unique())
# Out:
# ['LMV2', 'HMV', 'LMV2+WC', 'LMV1', 'UC LOOP']

# %% [markdown]
# How many entries do we have per vehicle type?

# %%
data.groupby('vehicle_type_raw').count()
# Out:
#                   created_at_timestamp  event_emitted_timestamp  event_number  \
# vehicle_type_raw
# HMV                              16683                    16683         16683
# LMV1                               349                      349           349
# LMV2                            276771                   276771        276771
# LMV2+WC                           5940                     5940          5940
# UC LOOP                             34                       34            34
#
#                   event_timestamp  klokketime    lane  length  qspeed  \
# vehicle_type_raw
# HMV                         16683       16683   16683   16683   16683
# LMV1                          349         349     349     349     349
# LMV2                       276771      276771  276771  276771  276771
# LMV2+WC                      5940        5940    5940    5940    5940
# UC LOOP                        34          34      34      34      34
#
#                   region_id   speed  time_gap  traffic_registration_point_id  \
# vehicle_type_raw
# HMV                   16683   16683     16683                          16683
# LMV1                    349     349       349                            349
# LMV2                 276771  276771    276771                         276771
# LMV2+WC                5940    5940      5940                           5940
# UC LOOP                  34      34        34                             34
#
#                   valid_classification  valid_event  valid_length  \
# vehicle_type_raw
# HMV                              16683        16683         16683
# LMV1                               349          349           349
# LMV2                            276771       276771        276771
# LMV2+WC                           5940         5940          5940
# UC LOOP                             34           34            34
#
#                   valid_speed  vehicle_type  weight  \
# vehicle_type_raw
# HMV                     16683         16683   16683
# LMV1                      349           349     349
# LMV2                   276771        276771  276771
# LMV2+WC                  5940          5940    5940
# UC LOOP                    34             0      34
#
#                   with_traffic_registration_point_direction  wrong_direction
# vehicle_type_raw
# HMV                                                   16683            16683
# LMV1                                                    349              349
# LMV2                                                 276771           276771
# LMV2+WC                                                5940             5940
# UC LOOP                                                  34               34

# %% [markdown]
# What happens when you group by two columns using the following syntax and then calculate mean values?
#
# ```
# grouped_data2 = data.groupby(['vehicle_type', 'lane'])
# ```

# %%
grouped_data2 = data.groupby(['vehicle_type', 'vehicle_type_raw', 'lane'])

# %%
grouped_data2.mean()
# Out:
#                                     event_number  klokketime     length  \
# vehicle_type vehicle_type_raw lane
# 1.0          LMV1             1     2.762780e+07   12.613333   0.969333
#                               2     2.763893e+07   12.666667   0.874603
#                               3     2.767453e+07   13.558559   0.898198
#                               4     2.764429e+07   12.940000   0.704000
# 2.0          LMV2             1     2.769308e+07   12.241173   4.544464
#                               2     2.769763e+07   14.402027   4.581179
#                               3     2.770199e+07   13.424781   4.606052
#                               4     2.770197e+07   14.068516   4.527683
# 3.0          HMV              1     2.769706e+07   12.605156   9.062822
#                               2     2.769159e+07   12.745690   8.346408
#                               3     2.768972e+07   12.061654  10.480072
#                               4     2.768888e+07   11.868481  10.528438
# 4.0          LMV2+WC          1     2.769477e+07   13.651596   8.740957
#                               2     2.769564e+07   13.967552   8.789381
#                               3     2.769418e+07   13.898705   8.796535
#                               4     2.769267e+07   13.598692   8.783763
#
#                                       qspeed  region_id      speed   time_gap  \
# vehicle_type vehicle_type_raw lane
# 1.0          LMV1             1     1.858667        1.0  84.693333  22.145333
#                               2     1.798413        1.0  80.171429  23.846032
#                               3     1.698198        1.0  73.949550  18.855856
#                               4     1.508000        1.0  69.550000   8.975000
# 2.0          LMV2             1     0.723147        1.0  81.636192  33.712624
#                               2     0.670361        1.0  82.090018  36.546495
#                               3     0.698132        1.0  76.172763  10.068626
#                               4     0.595232        1.0  75.022571   9.580896
# 3.0          HMV              1     0.740841        1.0  79.695929  38.607598
#                               2     0.792529        1.0  81.834195  72.014943
#                               3     0.550767        1.0  73.023578  14.074939
#                               4     0.402748        1.0  72.396172  14.212725
# 4.0          LMV2+WC          1     0.406117        1.0  80.346011  66.112234
#                               2     0.427729        1.0  79.512094  65.046608
#                               3     0.384615        1.0  74.011500   8.312643
#                               4     0.351174        1.0  73.149904   8.493113
#
#                                     traffic_registration_point_id  \
# vehicle_type vehicle_type_raw lane
# 1.0          LMV1             1                               1.0
#                               2                               1.0
#                               3                               1.0
#                               4                               1.0
# 2.0          LMV2             1                               1.0
#                               2                               1.0
#                               3                               1.0
#                               4                               1.0
# 3.0          HMV              1                               1.0
#                               2                               1.0
#                               3                               1.0
#                               4                               1.0
# 4.0          LMV2+WC          1                               1.0
#                               2                               1.0
#                               3                               1.0
#                               4                               1.0
#
#                                     valid_classification  valid_event  \
# vehicle_type vehicle_type_raw lane
# 1.0          LMV1             1                 0.053333          1.0
#                               2                 0.047619          1.0
#                               3                 0.027027          1.0
#                               4                 0.020000          1.0
# 2.0          LMV2             1                 0.705092          1.0
#                               2                 0.727715          1.0
#                               3                 0.695295          1.0
#                               4                 0.733324          1.0
# 3.0          HMV              1                 0.689281          1.0
#                               2                 0.685345          1.0
#                               3                 0.754418          1.0
#                               4                 0.816193          1.0
# 4.0          LMV2+WC          1                 0.832447          1.0
#                               2                 0.825959          1.0
#                               3                 0.830160          1.0
#                               4                 0.840323          1.0
#
#                                     valid_length  valid_speed  weight  \
# vehicle_type vehicle_type_raw lane
# 1.0          LMV1             1         0.053333     0.253333     0.0
#                               2         0.047619     0.253968     0.0
#                               3         0.018018     0.207207     0.0
#                               4         0.020000     0.250000     0.0
# 2.0          LMV2             1         0.704839     0.704997     0.0
#                               2         0.727578     0.728125     0.0
#                               3         0.695181     0.695399     0.0
#                               4         0.733152     0.733315     0.0
# 3.0          HMV              1         0.689281     0.689281     0.0
#                               2         0.685345     0.685345     0.0
#                               3         0.754289     0.755063     0.0
#                               4         0.816060     0.816060     0.0
# 4.0          LMV2+WC          1         0.832447     0.832447     0.0
#                               2         0.825959     0.825959     0.0
#                               3         0.830160     0.830160     0.0
#                               4         0.839938     0.839938     0.0
#
#                                     with_traffic_registration_point_direction  \
# vehicle_type vehicle_type_raw lane
# 1.0          LMV1             1                                           1.0
#                               2                                           0.0
#                               3                                           1.0
#                               4                                           0.0
# 2.0          LMV2             1                                           1.0
#                               2                                           0.0
#                               3                                           1.0
#                               4                                           0.0
# 3.0          HMV              1                                           1.0
#                               2                                           0.0
#                               3                                           1.0
#                               4                                           0.0
# 4.0          LMV2+WC          1                                           1.0
#                               2                                           0.0
#                               3                                           1.0
#                               4                                           0.0
#
#                                     wrong_direction
# vehicle_type vehicle_type_raw lane
# 1.0          LMV1             1            0.000000
#                               2            0.000000
#                               3            0.000000
#                               4            0.000000
# 2.0          LMV2             1            0.000032
#                               2            0.000068
#                               3            0.000000
#                               4            0.000000
# 3.0          HMV              1            0.000000
#                               2            0.000000
#                               3            0.000129
#                               4            0.000133
# 4.0          LMV2+WC          1            0.000000
#                               2            0.000000
#                               3            0.000000
#                               4            0.000000

# %%
data['vehicle_type'].unique()
# Out:
# array([ 2.,  3.,  4.,  1., nan])

# %%
data['vehicle_type_raw'].unique()
# Out:
# array(['LMV2', 'HMV', 'LMV2+WC', 'LMV1', 'UC LOOP'], dtype=object)
