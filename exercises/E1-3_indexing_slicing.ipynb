# %% [markdown]
# # Indexing, Slicing and Subsetting DataFrames in Python
#
# What happens when you execute:
#
#     - data[0:1]
#     - data[:4]
#     - data[:-1]

# %%
import pandas as pd

# %%
data = pd.read_csv('data/trafikkregistreringspunkt_4_-_uke_42_og_43_2020.csv')

# %%
data[0:1]
# Out:
#        created_at_timestamp   event_emitted_timestamp  event_number  \
# 0  2020-10-26, 02:08:22.356  2020-10-25, 23:58:03.524      10263259
#
#             event_timestamp  klokketime  lane  length  qspeed  region_id  \
# 0  2020-10-25, 23:58:03.524          23     2     4.6     0.0          1
#
#    speed  ...  traffic_registration_point_id  valid_classification  \
# 0   53.4  ...                              4                  True
#
#    valid_event  valid_length  valid_speed  vehicle_type  vehicle_type_raw  \
# 0         True          True         True           2.0              LMV2
#
#   weight  with_traffic_registration_point_direction  wrong_direction
# 0      0                                      False            False
#
# [1 rows x 21 columns]

# %%
data[:4]
# Out:
#        created_at_timestamp   event_emitted_timestamp  event_number  \
# 0  2020-10-26, 02:08:22.356  2020-10-25, 23:58:03.524      10263259
# 1  2020-10-26, 02:08:22.356  2020-10-25, 23:57:21.151      10263258
# 2  2020-10-26, 02:08:22.357  2020-10-25, 23:55:13.610      10263257
# 3  2020-10-26, 02:08:22.356  2020-10-25, 23:55:00.449      10263256
#
#             event_timestamp  klokketime  lane  length  qspeed  region_id  \
# 0  2020-10-25, 23:58:03.524          23     2     4.6     0.0          1
# 1  2020-10-25, 23:57:21.151          23     1     4.6     1.4          1
# 2  2020-10-25, 23:55:13.610          23     1     4.2     1.6          1
# 3  2020-10-25, 23:55:00.449          23     2     4.8     1.2          1
#
#    speed  ...  traffic_registration_point_id  valid_classification  \
# 0   53.4  ...                              4                  True
# 1   47.4  ...                              4                 False
# ...

# %%
data[:-1]
# Out:
#             created_at_timestamp   event_emitted_timestamp  event_number  \
# 0       2020-10-26, 02:08:22.356  2020-10-25, 23:58:03.524      10263259
# 1       2020-10-26, 02:08:22.356  2020-10-25, 23:57:21.151      10263258
# 2       2020-10-26, 02:08:22.357  2020-10-25, 23:55:13.610      10263257
# 3       2020-10-26, 02:08:22.356  2020-10-25, 23:55:00.449      10263256
# 4       2020-10-26, 02:08:22.356  2020-10-25, 23:53:10.410      10263255
# ...                          ...                       ...           ...
# 116442  2020-10-12, 03:06:44.951  2020-10-12, 00:05:32.530      10146817
# 116443  2020-10-12, 03:06:44.951  2020-10-12, 00:05:26.359      10146816
# 116444  2020-10-12, 03:06:44.951  2020-10-12, 00:05:22.859      10146815
# 116445  2020-10-12, 03:06:44.952  2020-10-12, 00:04:02.295      10146814
# 116446  2020-10-12, 03:06:44.956  2020-10-12, 00:03:50.664      10146813
#
#
#    speed  ...  traffic_registration_point_id  valid_classification  \
# ...

# %% [markdown]
# Select a subset of rows in the `data` DataFrame that contain data for vehicle type 2 that have been recorded before 10 am. How many rows did you end up with?
#
# You can use the `isin` command in Python to query a DataFrame based upon a list of values as follows:
#
# `data[data['label'].isin([element1, element2])]`

# %% [markdown]
# Use the `isin` function to find all rows that contain vehicle types 'LMV1' and 'HMV' in the data. How many records contain these values?

# %%
lmv1_hmv = data[data['vehicle_type_raw'].isin(['LMV1', 'HMV'])]

# %%
lmv1_hmv['vehicle_type_raw'].unique()
# Out:
# array(['HMV', 'LMV1'], dtype=object)

# %% [markdown]
# Experiment with other queries. Create a query that finds all rows with a length value > or equal to 4.0.

# %%
data[data['length'] >= 4.0]
# Out:
#             created_at_timestamp   event_emitted_timestamp  event_number  \
# 0       2020-10-26, 02:08:22.356  2020-10-25, 23:58:03.524      10263259
# 1       2020-10-26, 02:08:22.356  2020-10-25, 23:57:21.151      10263258
# 2       2020-10-26, 02:08:22.357  2020-10-25, 23:55:13.610      10263257
# 3       2020-10-26, 02:08:22.356  2020-10-25, 23:55:00.449      10263256
# 4       2020-10-26, 02:08:22.356  2020-10-25, 23:53:10.410      10263255
# ...                          ...                       ...           ...
# 116443  2020-10-12, 03:06:44.951  2020-10-12, 00:05:26.359      10146816
# 116444  2020-10-12, 03:06:44.951  2020-10-12, 00:05:22.859      10146815
# 116445  2020-10-12, 03:06:44.952  2020-10-12, 00:04:02.295      10146814
# 116446  2020-10-12, 03:06:44.956  2020-10-12, 00:03:50.664      10146813
# 116447  2020-10-12, 03:06:44.956  2020-10-12, 00:03:38.486      10146812
#
#                  event_timestamp  klokketime  lane  length  qspeed  region_id  \
# ...

# %% [markdown]
# The `~` symbol in Python can be used to return the OPPOSITE of the selection that you specify in Python. It is equivalent to *is not in*. Write the opposite queries of some of your previous answers.

# %%
not_lmv1_hmv = data[~data['vehicle_type_raw'].isin(['LMV1', 'HMV'])]

# %%
not_lmv1_hmv['vehicle_type_raw'].unique()
# Out:
# array(['LMV2', 'LMV2+WC', 'UC LOOP'], dtype=object)

# %%
data[~(data['length'] >= 4.0)]
# Out:
#             created_at_timestamp   event_emitted_timestamp  event_number  \
# 90      2020-10-26, 01:16:31.480  2020-10-25, 22:39:19.892      10263169
# 127     2020-10-26, 01:16:31.477  2020-10-25, 22:29:28.279      10263132
# 157     2020-10-26, 01:16:31.474  2020-10-25, 22:01:41.691      10263102
# 186     2020-10-26, 00:24:03.050  2020-10-25, 21:43:59.958      10263073
# 191     2020-10-26, 00:24:03.047  2020-10-25, 21:41:59.986      10263068
# ...                          ...                       ...           ...
# 116226  2020-10-12, 09:05:11.841  2020-10-12, 06:33:57.203      10147033
