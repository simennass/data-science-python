# %%
import pandas as pd

# %% [markdown]
# # Traffic data

# %%
data = pd.read_csv('Datasett/Trafikkregistreringsdatasett/trafikkregistreringspunkt 7 - uke 44 og 45.csv', sep=';')

# %%
data
# Out:
#             _id                         _index  _score                  _type  \
# 0      7-204867  traffic_event_vehicle_2020_11     NaN  traffic_event_vehicle
# 1      7-204866  traffic_event_vehicle_2020_11     NaN  traffic_event_vehicle
# 2      7-204865  traffic_event_vehicle_2020_11     NaN  traffic_event_vehicle
# 3      7-204864  traffic_event_vehicle_2020_11     NaN  traffic_event_vehicle
# 4      7-204863  traffic_event_vehicle_2020_11     NaN  traffic_event_vehicle
# ...         ...                            ...     ...                    ...
# 48134  7-156733  traffic_event_vehicle_2020_10     NaN  traffic_event_vehicle
# 48135  7-156732  traffic_event_vehicle_2020_10     NaN  traffic_event_vehicle
# 48136  7-156731  traffic_event_vehicle_2020_10     NaN  traffic_event_vehicle
# 48137  7-156730  traffic_event_vehicle_2020_10     NaN  traffic_event_vehicle
# 48138  7-156729  traffic_event_vehicle_2020_10     NaN  traffic_event_vehicle
#
#        county_id      created_at_timestamp datalogger_type  \
# 0             18  2020-11-09, 02:18:00.829    LOOP_MONITOR
# 1             18  2020-11-09, 02:18:00.829    LOOP_MONITOR
# 2             18  2020-11-09, 02:18:00.828    LOOP_MONITOR
# 3             18  2020-11-09, 02:18:00.829    LOOP_MONITOR
# 4             18  2020-11-09, 02:18:00.828    LOOP_MONITOR
# ...          ...                       ...             ...
# 48134         18  2020-10-26, 03:01:41.003    LOOP_MONITOR
# 48135         18  2020-10-26, 03:01:41.002    LOOP_MONITOR
# 48136         18  2020-10-26, 03:01:41.002    LOOP_MONITOR
# 48137         18  2020-10-26, 03:01:41.002    LOOP_MONITOR
# 48138         18  2020-10-26, 03:01:41.002    LOOP_MONITOR
#
#         event_emitted_timestamp  event_number           event_timestamp  ...  \
# 0      2020-11-08, 23:53:13.359        204867  2020-11-08, 23:53:12.230  ...
# 1      2020-11-08, 23:53:07.409        204866  2020-11-08, 23:53:06.030  ...
# 2      2020-11-08, 23:51:05.419        204865  2020-11-08, 23:51:04.010  ...
# 3      2020-11-08, 23:43:39.509        204864  2020-11-08, 23:43:38.220  ...
# 4      2020-11-08, 23:39:34.429        204863  2020-11-08, 23:39:32.110  ...
# ...                         ...           ...                       ...  ...
# 48134  2020-10-26, 00:32:28.609        156733  2020-10-26, 00:32:26.830  ...
# 48135  2020-10-26, 00:13:21.659        156732  2020-10-26, 00:13:20.260  ...
# 48136  2020-10-26, 00:13:19.669        156731  2020-10-26, 00:13:17.890  ...
# 48137  2020-10-26, 00:13:16.700        156730  2020-10-26, 00:13:14.830  ...
# 48138  2020-10-26, 00:03:24.699        156729  2020-10-26, 00:03:22.190  ...
#
#       valid_classification  valid_event  valid_length valid_speed  \
# 0                     True         True          True        True
# 1                     True         True          True        True
# 2                     True         True          True        True
# 3                     True         True          True        True
# 4                     True         True          True        True
# ...                    ...          ...           ...         ...
# 48134                 True         True          True        True
# 48135                 True         True          True        True
# 48136                 True         True          True        True
# 48137                 True         True          True        True
# 48138                 True         True          True        True
#
#       vehicle_type  vehicle_type_quality vehicle_type_raw weight  \
# 0                2                  2222                2    NaN
# 1                2                  2222                2    NaN
# 2               72                  2222               72    NaN
# 3                4                  2222                4    NaN
# 4                8                  6222                8    NaN
# ...            ...                   ...              ...    ...
# 48134            2                  2222                2    NaN
# 48135            2                  2222                2    NaN
# 48136            2                  2222                2    NaN
# 48137            2                  2222                2    NaN
# 48138            3                  2222                3    NaN
#
#        with_traffic_registration_point_direction  wrong_direction
# 0                                          False            False
# 1                                           True            False
# 2                                           True            False
# 3                                          False            False
# 4                                           True            False
# ...                                          ...              ...
# 48134                                       True            False
# 48135                                      False            False
# 48136                                       True            False
# 48137                                       True            False
# 48138                                      False            False
#
# [48139 rows x 29 columns]

# %%
data.isna().sum()
# Out:
# _id                                              0
# _index                                           0
# _score                                       48139
# _type                                            0
# county_id                                        0
# created_at_timestamp                             0
# datalogger_type                                  0
# event_emitted_timestamp                          0
# event_number                                     0
# event_timestamp                                  0
# firmware_version                                 0
# klokketime                                       0
# lane                                             0
# length                                           0
# qspeed                                           0
# region_id                                        0
# speed                                            0
# time_gap                                         0
# traffic_registration_point_id                    0
# valid_classification                             0
# valid_event                                      0
# valid_length                                     0
# valid_speed                                      0
# vehicle_type                                     0
# vehicle_type_quality                             0
# vehicle_type_raw                                 0
# weight                                       48139
# with_traffic_registration_point_direction        0
# wrong_direction                                  0
# dtype: int64

# %%
data.dtypes
# Out:
# _id                                           object
# _index                                        object
# _score                                       float64
# _type                                         object
# county_id                                      int64
# created_at_timestamp                          object
# datalogger_type                               object
# event_emitted_timestamp                       object
# event_number                                   int64
# event_timestamp                               object
# firmware_version                              object
# klokketime                                     int64
# lane                                           int64
# length                                        object
# qspeed                                        object
# region_id                                      int64
# speed                                         object
# time_gap                                      object
# traffic_registration_point_id                  int64
# valid_classification                            bool
# valid_event                                     bool
# valid_length                                    bool
# valid_speed                                     bool
# vehicle_type                                   int64
# vehicle_type_quality                           int64
# vehicle_type_raw                               int64
# weight                                       float64
# with_traffic_registration_point_direction       bool
# wrong_direction                                 bool
# dtype: object

# %%
data['length'] = data['length'].map(lambda x: float(x.replace(',', '.')))

# %%
data['qspeed'] = data['qspeed'].map(lambda x: float(x.replace(',', '.')))

# %%
data['speed'] = data['speed'].map(lambda x: float(x.replace(',', '.')))

# %%
data['time_gap'] = data['time_gap'].map(lambda x: float(x.replace(',', '.')))

# %%
data['_score'].unique()
# Out:
# array([nan])

# %%
data.drop(columns=['_score'], inplace=True)

# %%
data['_type'].unique()
# Out:
# array(['traffic_event_vehicle'], dtype=object)

# %%
data.drop(columns=['_type'], inplace=True)

# %%
data['county_id'].unique()
# Out:
# array([18])

# %%
data.drop(columns=['county_id'], inplace=True)

# %%
data['datalogger_type'].unique()
# Out:
# array(['LOOP_MONITOR'], dtype=object)

# %%
data.drop(columns=['datalogger_type'], inplace=True)

# %%
data['firmware_version'].unique()
# Out:
# array(['1.14.414/41.4'], dtype=object)

# %%
data.drop(columns=['firmware_version'], inplace=True)

# %%
data['_index'].unique()
# Out:
# array(['traffic_event_vehicle_2020_11', 'traffic_event_vehicle_2020_10'],
#       dtype=object)

# %%
data.drop(columns=['_index'], inplace=True)

# %%
data.set_index('event_number')
# Out:
#                    _id      created_at_timestamp   event_emitted_timestamp  \
# event_number
# 204867        7-204867  2020-11-09, 02:18:00.829  2020-11-08, 23:53:13.359
# 204866        7-204866  2020-11-09, 02:18:00.829  2020-11-08, 23:53:07.409
# 204865        7-204865  2020-11-09, 02:18:00.828  2020-11-08, 23:51:05.419
# 204864        7-204864  2020-11-09, 02:18:00.829  2020-11-08, 23:43:39.509
# 204863        7-204863  2020-11-09, 02:18:00.828  2020-11-08, 23:39:34.429
# ...                ...                       ...                       ...
# 156733        7-156733  2020-10-26, 03:01:41.003  2020-10-26, 00:32:28.609
# 156732        7-156732  2020-10-26, 03:01:41.002  2020-10-26, 00:13:21.659
# 156731        7-156731  2020-10-26, 03:01:41.002  2020-10-26, 00:13:19.669
# 156730        7-156730  2020-10-26, 03:01:41.002  2020-10-26, 00:13:16.700
# 156729        7-156729  2020-10-26, 03:01:41.002  2020-10-26, 00:03:24.699
#
#                        event_timestamp  klokketime  lane  length  qspeed  \
# event_number
# 204867        2020-11-08, 23:53:12.230          23     2     4.4     0.0
# 204866        2020-11-08, 23:53:06.030          23     1     4.5     0.1
# 204865        2020-11-08, 23:51:04.010          23     1     9.9     0.8
# 204864        2020-11-08, 23:43:38.220          23     2     5.0     0.3
# 204863        2020-11-08, 23:39:32.110          23     1    18.4     0.4
# ...                                ...         ...   ...     ...     ...
# 156733        2020-10-26, 00:32:26.830           0     1     5.0     0.3
# 156732        2020-10-26, 00:13:20.260           0     2     4.4     0.2
# 156731        2020-10-26, 00:13:17.890           0     1     3.9     2.0
# 156730        2020-10-26, 00:13:14.830           0     1     3.8     0.1
# 156729        2020-10-26, 00:03:22.190           0     2     9.1     0.2
#
#               region_id  speed  ...  valid_classification  valid_event  \
# event_number                    ...
# 204867                1   57.0  ...                  True         True
# 204866                1   58.1  ...                  True         True
# 204865                1   70.1  ...                  True         True
# 204864                1   61.9  ...                  True         True
# 204863                1   67.4  ...                  True         True
# ...                 ...    ...  ...                   ...          ...
# 156733                1   62.5  ...                  True         True
# 156732                1   59.2  ...                  True         True
# 156731                1   65.6  ...                  True         True
# 156730                1   67.0  ...                  True         True
# 156729                1   57.8  ...                  True         True
#
#               valid_length  valid_speed  vehicle_type  vehicle_type_quality  \
# event_number
# 204867                True         True             2                  2222
# 204866                True         True             2                  2222
# 204865                True         True            72                  2222
# 204864                True         True             4                  2222
# 204863                True         True             8                  6222
# ...                    ...          ...           ...                   ...
# 156733                True         True             2                  2222
# 156732                True         True             2                  2222
# 156731                True         True             2                  2222
# 156730                True         True             2                  2222
# 156729                True         True             3                  2222
#
#               vehicle_type_raw  weight  \
# event_number
# 204867                       2     NaN
# 204866                       2     NaN
# 204865                      72     NaN
# 204864                       4     NaN
# 204863                       8     NaN
# ...                        ...     ...
# 156733                       2     NaN
# 156732                       2     NaN
# 156731                       2     NaN
# 156730                       2     NaN
# 156729                       3     NaN
#
#               with_traffic_registration_point_direction  wrong_direction
# event_number
# 204867                                            False            False
# 204866                                             True            False
# 204865                                             True            False
# 204864                                            False            False
# 204863                                             True            False
# ...                                                 ...              ...
# 156733                                             True            False
# 156732                                            False            False
# 156731                                             True            False
# 156730                                             True            False
# 156729                                            False            False
#
# [48139 rows x 22 columns]

# %%
data.drop(columns=['_id'], inplace=True)

# %%
data['vehicle_type'].dtype
# Out:
# dtype('int64')

# %%
data.drop(columns=['vehicle_type_quality'], inplace=True)

# %%
data.to_csv('./data/trafikkregistreringspunkt_7_-_uke_44_og_45_2020.csv', index=False)

# %% [markdown]
# # Weather data

# %%
data = pd.read_csv('Datasett/veardata/Veardata_Bjornfjell.csv', sep=';')

# %%
data
# Out:
#                                  DESCRIPTION  MVT_ID         MEASURE_TIME  \
# 0                      Relativ luftfuktighet       2  28.08.2020 10:10:00
# 1                             Lufttemperatur       1  28.08.2020 10:10:00
# 2                     Vindretning (0 - 360°)      10  28.08.2020 10:10:00
# 3        Akkumulert nedbør siste 10 minutter      22  28.08.2020 10:10:00
# 4                              Vindhastighet       9  28.08.2020 10:10:00
# ...                                      ...     ...                  ...
# 2043887                    Vegbanetemperatur       8  01.08.2017 00:00:00
# 2043888                             Vindkast      11  01.08.2017 00:00:00
# 2043889     Maks. vindkast siste 10 minutter      31  01.08.2017 00:00:00
# 2043890                       Lufttemperatur       1  01.08.2017 00:00:00
# 2043891      Duggpunktstemperatur (beregnet)       3  01.08.2017 00:00:00
#
#          VALUE
# 0         99,9
# 1         5,16
# 2          281
# 3            0
# 4         3,06
# ...        ...
# 2043887     12
# 2043888   5,61
# 2043889   6,14
# 2043890  10,68
# 2043891    9,6
#
# [2043892 rows x 4 columns]

# %%
data.MVT_ID.unique()
# Out:
# array([  2,   1,  10,  22,   9,  25,  14,  11, 200,  31,   3,   8,   7])

# %%
data['VALUE'] = data['VALUE'].map(lambda x: float(x.replace(',', '.')))

# %%
# extract data for 'UNIT'
def convert_to_column(unitstr, data):
    unit = data[data['DESCRIPTION'] == unitstr].copy()
    unit.rename(columns={'VALUE': unitstr}, inplace=True)
    return unit[[unitstr, 'MEASURE_TIME']]

# %%
unit_df = []
for unitstr in data.DESCRIPTION.unique():
    unit_df.append(convert_to_column(unitstr, data))

# %%
data
# Out:
#                                  DESCRIPTION  MVT_ID         MEASURE_TIME  \
# 0                      Relativ luftfuktighet       2  28.08.2020 10:10:00
# 1                             Lufttemperatur       1  28.08.2020 10:10:00
# 2                     Vindretning (0 - 360°)      10  28.08.2020 10:10:00
# 3        Akkumulert nedbør siste 10 minutter      22  28.08.2020 10:10:00
# 4                              Vindhastighet       9  28.08.2020 10:10:00
# ...                                      ...     ...                  ...
# 2043887                    Vegbanetemperatur       8  01.08.2017 00:00:00
# 2043888                             Vindkast      11  01.08.2017 00:00:00
# 2043889     Maks. vindkast siste 10 minutter      31  01.08.2017 00:00:00
# 2043890                       Lufttemperatur       1  01.08.2017 00:00:00
# 2043891      Duggpunktstemperatur (beregnet)       3  01.08.2017 00:00:00
#
#           VALUE
# 0         99.90
# 1          5.16
# 2        281.00
# 3          0.00
# 4          3.06
# ...         ...
# 2043887   12.00
# 2043888    5.61
# 2043889    6.14
# 2043890   10.68
# 2043891    9.60
#
# [2043892 rows x 4 columns]

# %%
data.dtypes
# Out:
# DESCRIPTION      object
# MVT_ID            int64
# MEASURE_TIME     object
# VALUE           float64
# dtype: object

# %%
data_time = data[['MEASURE_TIME']].copy()

# %%
for unit in unit_df:
    data_time = pd.merge(left=data_time, right=unit, left_on='MEASURE_TIME', how='left', right_on='MEASURE_TIME')

# %%
data_time
# Out:
#                 MEASURE_TIME  Relativ luftfuktighet  Lufttemperatur  \
# 0        28.08.2020 10:10:00                   99.9            5.16
# 1        28.08.2020 10:10:00                   99.9            5.16
# 2        28.08.2020 10:10:00                   99.9            5.16
# 3        28.08.2020 10:10:00                   99.9            5.16
# 4        28.08.2020 10:10:00                   99.9            5.16
# ...                      ...                    ...             ...
# 2043887  01.08.2017 00:00:00                   92.9           10.68
# 2043888  01.08.2017 00:00:00                   92.9           10.68
# 2043889  01.08.2017 00:00:00                   92.9           10.68
# 2043890  01.08.2017 00:00:00                   92.9           10.68
# 2043891  01.08.2017 00:00:00                   92.9           10.68
#
#          Vindretning (0 - 360°)  Akkumulert nedbør siste 10 minutter  \
# 0                         281.0                                  0.0
# 1                         281.0                                  0.0
# 2                         281.0                                  0.0
# 3                         281.0                                  0.0
# 4                         281.0                                  0.0
# ...                         ...                                  ...
# 2043887                   107.0                                  0.0
# 2043888                   107.0                                  0.0
# 2043889                   107.0                                  0.0
# 2043890                   107.0                                  0.0
# 2043891                   107.0                                  0.0
#
#          Vindhastighet  Nedbørsintensitet  Sikt i nedbør  Vindkast  \
# 0                 3.06               0.00        19999.0      3.62
# 1                 3.06               0.00        19999.0      3.62
# 2                 3.06               0.00        19999.0      3.62
# 3                 3.06               0.00        19999.0      3.62
# 4                 3.06               0.00        19999.0      3.62
# ...                ...                ...            ...       ...
# 2043887           3.57               0.28        20000.0      5.61
# 2043888           3.57               0.28        20000.0      5.61
# 2043889           3.57               0.28        20000.0      5.61
# 2043890           3.57               0.28        20000.0      5.61
# 2043891           3.57               0.28        20000.0      5.61
#
#          Vindkastretning (0 - 360°)  Maks. vindkast siste 10 minutter  \
# 0                             265.0                              4.81
# 1                             265.0                              4.81
# 2                             265.0                              4.81
# 3                             265.0                              4.81
# 4                             265.0                              4.81
# ...                             ...                               ...
# 2043887                       128.0                              6.14
# 2043888                       128.0                              6.14
# 2043889                       128.0                              6.14
# 2043890                       128.0                              6.14
# 2043891                       128.0                              6.14
#
#          Duggpunktstemperatur (beregnet)  Vegbanetemperatur  Nedbørstype
# 0                                    5.1                6.5          NaN
# 1                                    5.1                6.5          NaN
# 2                                    5.1                6.5          NaN
# 3                                    5.1                6.5          NaN
# 4                                    5.1                6.5          NaN
# ...                                  ...                ...          ...
# 2043887                              9.6               12.0        512.0
# 2043888                              9.6               12.0        512.0
# 2043889                              9.6               12.0        512.0
# 2043890                              9.6               12.0        512.0
# 2043891                              9.6               12.0        512.0
#
# [2043892 rows x 14 columns]

# %%
data_time.dtypes
# Out:
# MEASURE_TIME                            object
# Relativ luftfuktighet                  float64
# Lufttemperatur                         float64
# Vindretning (0 - 360°)                 float64
# Akkumulert nedbør siste 10 minutter    float64
# Vindhastighet                          float64
# Nedbørsintensitet                      float64
# Sikt i nedbør                          float64
# Vindkast                               float64
# Vindkastretning (0 - 360°)             float64
# Maks. vindkast siste 10 minutter       float64
# Duggpunktstemperatur (beregnet)        float64
# Vegbanetemperatur                      float64
# Nedbørstype                            float64
# dtype: object

# %%
data.to_csv('./data/vaerdata_bjornfjellet.csv', index=False)
